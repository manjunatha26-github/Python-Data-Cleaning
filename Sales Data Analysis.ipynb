# %%
import pandas as pd
df = pd.read_excel("C:/Users/DELL/Downloads/sales/sales_v1.xlsx")

# %%
df.head(5)
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government  Germany  Carretera           NaN      1513.0
# 1  Government  Germany      Paseo           NaN      1006.0
# 2  Government   Canada      Paseo           NaN      1725.0
# 3  Government  Germany      Paseo           NaN      1513.0
# 4  Government  Germany       Velo           NaN      1006.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                    3         350     529550.0        0.0  529550.0
# 1                   10         350     352100.0        0.0  352100.0
# 2                   10         350     603750.0        0.0  603750.0
# 3                   10         350     529550.0        0.0  529550.0
# 4                  120         350     352100.0        0.0  352100.0
#
#        COGS    Profit       Date  Month Number Month Name  Year
# 0  393380.0  136170.0 2014-12-01            12   December  2014
# ...

# %%
df.shape
# Out:
# (700, 16)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               segment  country    product discount_band  units_sold  \
# 0          Government  Germany  Carretera   No Discount      1513.0
# 1          Government  Germany      Paseo   No Discount      1006.0
# 2          Government   Canada      Paseo   No Discount      1725.0
# 3          Government  Germany      Paseo   No Discount      1513.0
# 4          Government  Germany       Velo   No Discount      1006.0
# ..                ...      ...        ...           ...         ...
# 695         Midmarket   Canada      Paseo          High      1614.0
# 696         Midmarket   Canada      Paseo          High      2559.0
# 697        Enterprise  Germany      Paseo          High      1085.0
# 698         Midmarket  Germany      Paseo          High      1175.0
# 699  Channel Partners      USA      Paseo          High       914.0
#
#      manufacturing_price  sale_price  gross_sales  discounts      sales  \
# ...

# %%
df.tail()
# Out:
#               Segment  Country Product Discount Band  Units Sold  \
# 695         Midmarket   Canada   Paseo          High      1614.0
# 696         Midmarket   Canada   Paseo          High      2559.0
# 697        Enterprise  Germany   Paseo          High      1085.0
# 698         Midmarket  Germany   Paseo          High      1175.0
# 699  Channel Partners      USA   Paseo          High       914.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts      Sales  \
# 695                   10          15      24210.0    3631.50   20578.50
# 696                   10          15      38385.0    5757.75   32627.25
# 697                   10         125     135625.0   20343.75  115281.25
# 698                   10          15      17625.0    2643.75   14981.25
# 699                   10          12      10968.0    1645.20    9322.80
#
#          COGS    Profit       Date  Month Number Month Name  Year
# 695   16140.0   4438.50 2014-04-01             4      April  2014
# ...

# %%
df.columns
# Out:
# Index(['segment', 'country', 'product', 'discount_band', 'units_sold',
#        'manufacturing_price', 'sale_price', 'gross_sales', 'discounts',
#        'sales', 'cogs', 'profit', 'date', 'month_number', 'month_name',
#        'year'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of               segment  country    product discount_band  units_sold  \
# 0          Government  Germany  Carretera   No Discount      1513.0
# 1          Government  Germany      Paseo   No Discount      1006.0
# 2          Government   Canada      Paseo   No Discount      1725.0
# 3          Government  Germany      Paseo   No Discount      1513.0
# 4          Government  Germany       Velo   No Discount      1006.0
# ..                ...      ...        ...           ...         ...
# 695         Midmarket   Canada      Paseo          High      1614.0
# 696         Midmarket   Canada      Paseo          High      2559.0
# 697        Enterprise  Germany      Paseo          High      1085.0
# 698         Midmarket  Germany      Paseo          High      1175.0
# 699  Channel Partners      USA      Paseo          High       914.0
#
#      manufacturing_price  sale_price  gross_sales  discounts      sales  \
# ...

# %%
df.describe(include="all")
# Out:
#            Segment  Country Product Discount Band   Units Sold  \
# count          700      700     700           647   700.000000
# unique           5        5       6             3          NaN
# top     Government  Germany   Paseo          High          NaN
# freq           300      140     202           245          NaN
# mean           NaN      NaN     NaN           NaN  1608.294286
# min            NaN      NaN     NaN           NaN   200.000000
# 25%            NaN      NaN     NaN           NaN   905.000000
# 50%            NaN      NaN     NaN           NaN  1542.500000
# 75%            NaN      NaN     NaN           NaN  2229.125000
# max            NaN      NaN     NaN           NaN  4492.500000
# std            NaN      NaN     NaN           NaN   867.427859
#
#         Manufacturing Price  Sale Price   Gross Sales      Discounts  \
# count            700.000000  700.000000  7.000000e+02     700.000000
# ...

# %%
import numpy as ny

# %%
df.isnull().sum()
# Out:
# Segment                0
# Country                0
# Product                0
# Discount Band          0
# Units Sold             0
# Manufacturing Price    0
# Sale Price             0
# Gross Sales            0
# Discounts              0
#  Sales                 0
# COGS                   0
# Profit                 0
# Date                   0
# Month Number           0
# Month Name             0
# Year                   0
# dtype: int64

# %%
df['Discount Band'] = df['Discount Band'].fillna("No Discount")

# %%
df
# Out:
#               Segment  Country    Product Discount Band  Units Sold  \
# 0          Government  Germany  Carretera   No Discount      1513.0
# 1          Government  Germany      Paseo   No Discount      1006.0
# 2          Government   Canada      Paseo   No Discount      1725.0
# 3          Government  Germany      Paseo   No Discount      1513.0
# 4          Government  Germany       Velo   No Discount      1006.0
# ..                ...      ...        ...           ...         ...
# 695         Midmarket   Canada      Paseo          High      1614.0
# 696         Midmarket   Canada      Paseo          High      2559.0
# 697        Enterprise  Germany      Paseo          High      1085.0
# 698         Midmarket  Germany      Paseo          High      1175.0
# 699  Channel Partners      USA      Paseo          High       914.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts      Sales  \
# 0                      3         350     529550.0       0.00  529550.00
# ...

# %%
df.columns
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['segment', 'country', 'product', 'discount_band', 'units_sold',
#        'manufacturing_price', 'sale_price', 'gross_sales', 'discounts',
#        'sales', 'cogs', 'profit', 'date', 'month_number', 'month_name',
#        'year'],
#       dtype='object')

# %%
df = df.rename(columns={'_sales':'sales'})

# %%
labels = ['Q1', 'Q2', 'Q3', 'Q4']
df['Quarter'] = pd.cut(
    df['month_number'],
    bins=[0, 3, 6, 9, 12],
    labels=labels
)

# %%
df.head(5)
# Out:
#       segment  country    product discount_band  units_sold  \
# 0  Government  Germany  Carretera   No Discount      1513.0
# 1  Government  Germany      Paseo   No Discount      1006.0
# 2  Government   Canada      Paseo   No Discount      1725.0
# 3  Government  Germany      Paseo   No Discount      1513.0
# 4  Government  Germany       Velo   No Discount      1006.0
#
#    manufacturing_price  sale_price  gross_sales  discounts     sales  \
# 0                    3         350     529550.0        0.0  529550.0
# 1                   10         350     352100.0        0.0  352100.0
# 2                   10         350     603750.0        0.0  603750.0
# 3                   10         350     529550.0        0.0  529550.0
# 4                  120         350     352100.0        0.0  352100.0
#
#        cogs    profit       date  month_number month_name  year Quaters  \
# 0  393380.0  136170.0 2014-12-01            12   December  2014      Q4
# ...

# %%
df[['month_number','month_name', 'Quarter']].drop_duplicates().sort_values('month_number')
# Out:
#     month_number month_name Quarter
# 32             1    January      Q1
# 6              2   February      Q1
# 7              3      March      Q1
# 11             4      April      Q2
# 41             5        May      Q2
# 1              6       June      Q2
# 24             7       July      Q3
# 22             8     August      Q3
# 5              9  September      Q3
# 8             10    October      Q4
# 2             11   November      Q4
# 0             12   December      Q4

# %%
df[['month_number']].head(10)
# Out:
#    month_number
# 0            12
# 1             6
# 2            11
# 3            12
# 4             6
# 5             9
# 6             2
# 7             3
# 8            10
# 9            12

# %%
df.columns
# Out:
# Index(['segment', 'country', 'product', 'discount_band', 'units_sold',
#        'manufacturing_price', 'sale_price', 'gross_sales', 'discounts',
#        'sales', 'cogs', 'profit', 'date', 'month_number', 'month_name', 'year',
#        'quaters', 'quarter'],
#       dtype='object')

# %%
df[['quaters','quarter']].head()
# Out:
#   quaters quarter
# 0      Q4      Q4
# 1      Q2      Q2
# 2      Q4      Q4
# 3      Q4      Q4
# 4      Q2      Q2

# %%
(df['quarter']==df['quaters']).all()
# Out:
# np.False_

# %%
df = df.drop('quaters', axis=1)

# %%
df.groupby('quarter')['profit'].sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16716\2594895841.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('quarter')['profit'].sum()
# quarter
# Q1    2632442.94
# Q2    3232378.45
# Q3    3501667.37
# Q4    7527213.50
# Name: profit, dtype: float64

# %%
df.columns
# Out:
# Index(['segment', 'country', 'product', 'discount_band', 'units_sold',
#        'manufacturing_price', 'sale_price', 'gross_sales', 'discounts',
#        'sales', 'cogs', 'profit', 'date', 'month_number', 'month_name', 'year',
#        'quarter'],
#       dtype='object')

# %%
df.groupby('segment')['profit'].sum()
# Out:
# segment
# Channel Partners    1.316803e+06
# Enterprise         -6.145456e+05
# Government          1.138817e+07
# Midmarket           6.601031e+05
# Small Business      4.143168e+06
# Name: profit, dtype: float64

# %%
# !pip install psycopg2-binary sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------------------------- ------------ 1.8/2.7 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 8.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 11.2 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# Step 1: Connect to PostgreSQL

username = "postgres"      # default user
password = "manju" # the password you set during installation
host = "localhost"         # if running locally
port = "5432"              # default PostgreSQL port
database = "project1"    # the database you created in pgAdmin

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 2: Load DataFrame into PostgreSQL
table_name = "customer"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'customer' in database 'project1'.
